# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %% [markdown]
# # Data Loading and EDA

# %%
df = pd.read_csv("AIML_Dataset.csv")

# %%
df.sample(5)
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 2850748   227  TRANSFER  162916.55  C1998085872            0.0
# 82233      10   PAYMENT     896.38   C544659199        29952.0
# 778000     39   PAYMENT    8489.80   C564623569            0.0
# 4125796   302  CASH_OUT  476039.26   C746922665        39933.0
# 4712083   332   CASH_IN   97178.65  C2060822957        60173.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2850748            0.00  C1164478130      1273551.65      1436468.20        0
# 82233          29055.62  M1510794408            0.00            0.00        0
# 778000             0.00  M1097419974            0.00            0.00        0
# 4125796            0.00  C1389483976       467478.93       943518.19        0
# 4712083       157351.65   C392557313       306358.73       209180.07        0
#
#          isFlaggedFraud
# 2850748               0
# 82233                 0
# 778000                0
# ...

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df[df['isFraud']==1]
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 251         1  TRANSFER     2806.00  C1420196421        2806.00
# 252         1  CASH_OUT     2806.00  C2101527076        2806.00
# 680         1  TRANSFER    20128.00   C137533655       20128.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                   0.0   C553264065            0.00            0.00        1
# ...

# %%
df['isFraud'].value_counts() #imbalanced dataset
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum() # no null values
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.duplicated().sum() # no duplicates
# Out:
# np.int64(0)

# %%
round((df['isFraud'].value_counts()[1] / df.shape[0]) *100,2) # highly imbalanced
# Out:
# np.float64(0.13)

# %% [markdown]
# # Data Analysis

# %%
df['type'].value_counts().plot(kind='bar',title = 'Transection Types')
plt.ylabel("# of Transections")
plt.xlabel("Transection Types")
plt.show()

# %%
fraud_by_type = df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
fraud_by_type.plot(kind='bar',title='Fraud by transection type',color='salmon')
plt.xlabel("Transection Type")
plt.ylabel("Fraud rate")
plt.show()

# %%
fraud_by_type
# Out:
# type
# TRANSFER    0.007688
# CASH_OUT    0.001840
# CASH_IN     0.000000
# DEBIT       0.000000
# PAYMENT     0.000000
# Name: isFraud, dtype: float64

# %%
df.describe(include='all')
# Out:
#                 step      type        amount     nameOrig  oldbalanceOrg  \
# count   6.362620e+06   6362620  6.362620e+06      6362620   6.362620e+06
# unique           NaN         5           NaN      6353307            NaN
# top              NaN  CASH_OUT           NaN  C1530544995            NaN
# freq             NaN   2237500           NaN            3            NaN
# mean    2.433972e+02       NaN  1.798619e+05          NaN   8.338831e+05
# std     1.423320e+02       NaN  6.038582e+05          NaN   2.888243e+06
# min     1.000000e+00       NaN  0.000000e+00          NaN   0.000000e+00
# 25%     1.560000e+02       NaN  1.338957e+04          NaN   0.000000e+00
# 50%     2.390000e+02       NaN  7.487194e+04          NaN   1.420800e+04
# 75%     3.350000e+02       NaN  2.087215e+05          NaN   1.073152e+05
# max     7.430000e+02       NaN  9.244552e+07          NaN   5.958504e+07
#
#         newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  \
# ...

# %%
sns.histplot(np.log1p(df['amount']),bins=100,kde=True,color='green')
plt.title("Transection amount distribution (log scaled)")
plt.xlabel("log(Amount + 1)")
plt.show()

# %%
sns.boxplot(df[df['amount']<50000],x = 'isFraud',y ='amount')
plt.title('Amount vs Fraud (filtered under 50k)')
plt.show()

# %%
df['balance_diff_Org'] = df['newbalanceOrig']  - df['oldbalanceOrg']
df['balance_diff_Dest'] = df['newbalanceDest'] - df['oldbalanceDest']

# %%
(df['balance_diff_Dest']<0).sum()
# Out:
# np.int64(1238864)

# %%
(df['balance_diff_Org']<0).sum()
# Out:
# np.int64(2874330)

# %%
frauds_per_step = df[df['isFraud'] == 1]['step'].value_counts().sort_index()
plt.plot(frauds_per_step.index,frauds_per_step.values,label="Frauds Per Step")
plt.xlabel("Step (Time)")
plt.ylabel("Number of Frauds")
plt.title("Frauds over time")
plt.show() 
# time independent

# %%
df.drop(columns = ['step'],inplace=True)

# %%
top_senders = df['nameOrig'].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C1530544995    3
# C545315117     3
# C724452879     3
# C1784010646    3
# C1677795071    3
# C1462946854    3
# C1065307291    3
# C1999539787    3
# C2098525306    3
# C400299098     3
# Name: count, dtype: int64

# %%
top_recievers = df['nameDest'].value_counts().head(10)
top_recievers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C1789550256     99
# C451111351      99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = df[df['isFraud'] == 1]['nameOrig'].value_counts().head(10)

# %%
fraud_users
# Out:
# nameOrig
# C1280323807    1
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C1039979813    1
# C2089752665    1
# C1614818636    1
# C40604503      1
# C1970706589    1
# Name: count, dtype: int64

# %%
fraud_types = df[df['type'].isin(['TRANSFER','CASH_OUT'])]
fraud_types['type'].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data = fraud_types,x='type',hue='isFraud')
plt.title("Fraud distribution in TRANSFER and CASH_OUT")
plt.show()

# %%
corr = df[['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']].corr()

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# %%
zero_after_transfer = df[
    (df['oldbalanceOrg'] > 0) &
    (df['newbalanceOrig'] == 0) &
    (df['type'].isin(["TRANSFER","cASH_OUT"]))
]

# %%
zero_after_transfer.head(5)
# Out:
#          type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2    TRANSFER     181.00  C1305486145         181.00             0.0
# 19   TRANSFER  215310.30  C1670993182         705.00             0.0
# 24   TRANSFER  311685.89  C1984094095       10835.00             0.0
# 78   TRANSFER   42712.39   C283039401       10363.39             0.0
# 123  TRANSFER  330757.04  C1494346128      103657.00             0.0
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2     C553264065            0.00            0.00        1               0
# 19   C1100439041        22425.00            0.00        0               0
# 24    C932583850         6267.00      2719172.89        0               0
# 78   C1330106945        57901.66        24044.18        0               0
# 123   C564160838        79676.00      1254956.07        0               0
#
#      balance_diff_Org  balance_diff_Dest
# 2             -181.00               0.00
# ...

# %% [markdown]
# ## Preprocessing and Feature Engineering

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
df_model = df.drop(columns = ['nameOrig','nameDest','isFlaggedFraud'],axis = 1)
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balance_diff_Org  balance_diff_Dest
# 0             0.0        0          -9839.64                0.0
# 1             0.0        0          -1864.28                0.0
# 2             0.0        1           -181.00                0.0
# 3             0.0        1           -181.00           -21182.0
# 4             0.0        0         -11668.14                0.0

# %%
cat_cols = ['type']
num_cols = ['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']

# %%
y = df_model['isFraud']
X = df_model.drop(columns=['isFraud'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,stratify = y)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num',StandardScaler(),num_cols),
        ('cat',OneHotEncoder(drop='first'),cat_cols)
    ],
    remainder='drop'
)

# %%
model_pipe = Pipeline([
    ('prep',preprocessor),
    ('clf',LogisticRegression(class_weight='balanced',max_iter=1000))
])

# %%
model_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = model_pipe.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97   1906322
#            1       0.02      0.94      0.04      2464
#
#     accuracy                           0.94   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.94      0.97   1908786

# %%
conf = confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(conf)
disp.plot()
plt.grid(False)
plt.show()

# %%
model_pipe.score(X_test,y_test)
# Out:
# 0.9447774658866944

# %%
import joblib

joblib.dump(model_pipe,"fraud_detection_pipeline.pkl")
# Out:
# ['fraud_detection_pipeline.pkl']

# %%
l = list(model_pipe.named_steps['prep'].named_transformers_['cat'].get_feature_names_out(cat_cols))

# %%
for i,cat in enumerate(l):
    l[i] = cat[5:]

# %%
l
# Out:
# ['CASH_OUT', 'DEBIT', 'PAYMENT', 'TRANSFER']
